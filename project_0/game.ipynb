# %% [markdown]
# # Игра угадай число

# %% [markdown]
# ## Угадываем рандомно:

# %%
#from game_v2 import score_game
#from game_v2 import random_predict
score_game(random_predict) #вызов функции
# Out:
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# попытка: 7 Предсказанное число: 10
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 75
# попытка: 7 Предсказанное число: 76
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 6
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 80
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 17
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 2
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# попытка: 7 Предсказанное число: 72
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 26
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 29
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 29
# попытка: 7 Предсказанное число: 30
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 87
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# попытка: 7 Предсказанное число: 14
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# попытка: 7 Предсказанное число: 10
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 8
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 63
# попытка: 7 Предсказанное число: 64
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 58
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 2
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 61
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# попытка: 7 Предсказанное число: 82
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 89
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# попытка: 7 Предсказанное число: 14
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# попытка: 7 Предсказанное число: 48
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# попытка: 7 Предсказанное число: 72
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 4
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# попытка: 7 Предсказанное число: 22
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 58
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 4
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# попытка: 7 Предсказанное число: 44
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# попытка: 7 Предсказанное число: 42
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 17
# попытка: 7 Предсказанное число: 16
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 26
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 8
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 26
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# попытка: 7 Предсказанное число: 10
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# попытка: 7 Предсказанное число: 68
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 24
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 29
# попытка: 7 Предсказанное число: 28
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 58
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# попытка: 7 Предсказанное число: 84
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 39
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# попытка: 6 Предсказанное число: 33
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 24
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 17
# попытка: 7 Предсказанное число: 16
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 26
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# попытка: 7 Предсказанное число: 72
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 93
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 63
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# попытка: 6 Предсказанное число: 33
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 89
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 24
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 56
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# попытка: 7 Предсказанное число: 66
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 78
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 4
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 78
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 87
# попытка: 7 Предсказанное число: 86
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 93
# попытка: 7 Предсказанное число: 92
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# попытка: 7 Предсказанное число: 22
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 75
# попытка: 7 Предсказанное число: 76
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 8
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 78
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 75
# попытка: 7 Предсказанное число: 76
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# попытка: 7 Предсказанное число: 44
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# попытка: 6 Предсказанное число: 37
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 8
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# попытка: 7 Предсказанное число: 46
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 58
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# попытка: 7 Предсказанное число: 14
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 24
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# попытка: 7 Предсказанное число: 82
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 8
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 93
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# попытка: 6 Предсказанное число: 33
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# попытка: 7 Предсказанное число: 66
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 61
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# попытка: 7 Предсказанное число: 98
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 93
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 87
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# попытка: 7 Предсказанное число: 72
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 17
# попытка: 7 Предсказанное число: 16
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 6
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 17
# попытка: 7 Предсказанное число: 18
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# попытка: 7 Предсказанное число: 14
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# попытка: 7 Предсказанное число: 98
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# попытка: 7 Предсказанное число: 54
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 56
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 89
# попытка: 7 Предсказанное число: 90
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# попытка: 7 Предсказанное число: 22
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# попытка: 7 Предсказанное число: 84
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 26
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# попытка: 7 Предсказанное число: 14
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# попытка: 7 Предсказанное число: 44
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 78
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 61
# попытка: 7 Предсказанное число: 60
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 17
# попытка: 7 Предсказанное число: 16
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 11
# попытка: 7 Предсказанное число: 10
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# попытка: 7 Предсказанное число: 72
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# попытка: 7 Предсказанное число: 54
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# попытка: 7 Предсказанное число: 70
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# попытка: 6 Предсказанное число: 37
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# попытка: 7 Предсказанное число: 22
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 78
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 93
# попытка: 7 Предсказанное число: 92
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# попытка: 7 Предсказанное число: 48
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 78
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# попытка: 7 Предсказанное число: 46
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 17
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 29
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# попытка: 7 Предсказанное число: 46
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# попытка: 7 Предсказанное число: 68
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# ...
# попытка: 6 Предсказанное число: 61
# попытка: 7 Предсказанное число: 60
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# попытка: 6 Предсказанное число: 33
# попытка: 7 Предсказанное число: 32
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 2
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 26
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# попытка: 7 Предсказанное число: 84
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 27
# попытка: 6 Предсказанное число: 29
# попытка: 7 Предсказанное число: 28
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 93
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 56
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 24
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 89
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 91
# попытка: 6 Предсказанное число: 89
# попытка: 7 Предсказанное число: 90
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 83
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 9
# попытка: 6 Предсказанное число: 7
# попытка: 7 Предсказанное число: 6
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 21
# попытка: 7 Предсказанное число: 22
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# попытка: 7 Предсказанное число: 52
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 75
# попытка: 7 Предсказанное число: 74
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# попытка: 6 Предсказанное число: 13
# попытка: 7 Предсказанное число: 14
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# попытка: 6 Предсказанное число: 25
# попытка: 7 Предсказанное число: 24
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# попытка: 6 Предсказанное число: 47
# попытка: 7 Предсказанное число: 46
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# попытка: 7 Предсказанное число: 96
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 31
# попытка: 5 Предсказанное число: 35
# попытка: 6 Предсказанное число: 33
# попытка: 7 Предсказанное число: 34
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 15
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 58
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 67
# попытка: 7 Предсказанное число: 66
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 19
# попытка: 5 Предсказанное число: 23
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 85
# попытка: 6 Предсказанное число: 87
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 2
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# попытка: 7 Предсказанное число: 52
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 73
# попытка: 6 Предсказанное число: 71
# попытка: 7 Предсказанное число: 72
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 79
# попытка: 7 Предсказанное число: 78
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 69
# попытка: 5 Предсказанное число: 65
# попытка: 6 Предсказанное число: 63
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 49
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 39
# попытка: 7 Предсказанное число: 40
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 12
# попытка: 4 Предсказанное число: 5
# попытка: 5 Предсказанное число: 1
# попытка: 6 Предсказанное число: 3
# попытка: 7 Предсказанное число: 4
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 59
# попытка: 6 Предсказанное число: 57
# попытка: 7 Предсказанное число: 58
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# попытка: 7 Предсказанное число: 44
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 62
# попытка: 4 Предсказанное число: 55
# попытка: 5 Предсказанное число: 51
# попытка: 6 Предсказанное число: 53
# попытка: 7 Предсказанное число: 54
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 25
# попытка: 3 Предсказанное число: 38
# попытка: 4 Предсказанное число: 45
# попытка: 5 Предсказанное число: 41
# попытка: 6 Предсказанное число: 43
# попытка: 7 Предсказанное число: 44
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 95
# попытка: 5 Предсказанное число: 99
# попытка: 6 Предсказанное число: 97
# попытка: 7 Предсказанное число: 98
# Загаданное число: 50
# попытка: 1 Предсказанное число: 50
# попытка: 2 Предсказанное число: 75
# попытка: 3 Предсказанное число: 88
# попытка: 4 Предсказанное число: 81
# попытка: 5 Предсказанное число: 77
# попытка: 6 Предсказанное число: 75
# попытка: 7 Предсказанное число: 76
# Ваш алгоритм угадывает число в среднем за: 5 попыток
# 5
